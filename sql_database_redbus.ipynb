# %%
##SQL DATABASE:
# !pip install pandas
# %pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import mysql.connector
import numpy as np

# %%
# csv to dataframe
df_andhra=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\andhra_busdetails.csv")
df_kerala=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\kerala_busdetails.csv")
df_tel=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\telangana_busdetails.csv")
df_har=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\haryana_busdetails.csv")
df_up=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\uttarpradesh_busdetails.csv")
df_raj=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\rajasthan_busdetails.csv")
df_ass=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\assam_busdetails.csv")
df_meg=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\meghalaya_busdetails.csv")
df_gj=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\gujarat_busdetails.csv")
df_pun=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\busdetailsall\punjab_busdetails.csv")
df_full1=pd.concat([df_andhra,df_kerala,df_tel,df_har,df_up,df_raj,df_ass,df_meg,df_gj,df_pun],ignore_index=True)
df_full1
# Out:
#                                     Bus_name  \
# 0                                   FRESHBUS
# 1                                   FRESHBUS
# 2                                   FRESHBUS
# 3                           AdSai RK Travels
# 4     RAMK HOLIDAYS (GMRK TOURS AND TRAVELS)
# ...                                      ...
# 1082                          Laxmi holidays
# 1083                                     NaN
# 1084                                     NaN
# 1085                                     NaN
# 1086                                     NaN
#
#                                    Bus_type Start_time End_time  \
# 0                 Electric A/C Seater (2+2)      22:40    05:45
# 1                 Electric A/C Seater (2+2)      22:55    05:55
# 2                 Electric A/C Seater (2+2)      23:35    06:30
# 3            Non A/C Seater / Sleeper (2+1)      21:50    04:35
# 4              Volvo A/C Semi Sleeper (2+2)      22:30    05:25
# ...

# %%
df_full1.columns
# Out:
# Index(['Bus_name', 'Bus_type', 'Start_time', 'End_time', 'Total_duration',
#        'Price', 'Seats_Available', 'Ratings', 'Route_link', 'Route_name'],
#       dtype='object')

# %%
df_full1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         505 non-null    object
#  1   Bus_type         489 non-null    object
#  2   Start_time       505 non-null    object
#  3   End_time         505 non-null    object
#  4   Total_duration   505 non-null    object
#  5   Price            504 non-null    object
#  6   Seats_Available  495 non-null    object
#  7   Ratings          505 non-null    object
#  8   Route_link       1087 non-null   object
#  9   Route_name       1087 non-null   object
# dtypes: object(10)
# memory usage: 85.1+ KB

# %%
df_full1["Price"]
# Out:
# 0           449
# 1           449
# 2           449
# 3       INR 560
# 4       INR 499
#          ...
# 1082    INR 430
# 1083        NaN
# 1084        NaN
# 1085        NaN
# 1086        NaN
# Name: Price, Length: 1087, dtype: object

# %%
# Ensure all values in the column are strings
df_full1["Price"] = df_full1["Price"].astype(str)

# Remove "INR" and any other non-numeric characters
df_full1["Price"] = df_full1["Price"].str.replace("INR", "", regex=False).str.strip()

# Convert to numeric, coercing errors to NaN
df_full1["Price"] = pd.to_numeric(df_full1["Price"], errors="coerce")

# Fill NaN values with 0
df_full1["Price"] = df_full1["Price"].fillna(0)

# %%
df_full1["Ratings"]
# Out:
# 0       4.7\n545
# 1       4.6\n427
# 2       4.6\n422
# 3        4.1\n68
# 4       4.5\n383
#           ...
# 1082    4.8\n547
# 1083         NaN
# 1084         NaN
# 1085         NaN
# 1086         NaN
# Name: Ratings, Length: 1087, dtype: object

# %%
df_full1["Ratings"] = df_full1["Ratings"].astype(str)
df_full1["Ratings"] = df_full1["Ratings"].str.replace("New", "")
df_full1["Ratings"] = df_full1["Ratings"].str.strip()
df_full1["Ratings"] = df_full1["Ratings"].str.split().str[0]
# Convert to numeric, coercing errors
df_full1["Ratings"] = pd.to_numeric(df_full1["Ratings"], errors='coerce')
df_full1["Ratings"].fillna(0, inplace=True)

print(df_full1["Ratings"])
# Out:
# 0       4.7
# 1       4.6
# 2       4.6
# 3       4.1
# 4       4.5
#        ...
# 1082    4.8
# 1083    0.0
# 1084    0.0
# 1085    0.0
# 1086    0.0
# Name: Ratings, Length: 1087, dtype: float64
# C:\Users\kumar\AppData\Local\Temp\ipykernel_15176\778395235.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_full1["Ratings"].fillna(0, inplace=True)

# %%
print(df_full1["Ratings"].unique())
# Out:
# [4.7 4.6 4.1 4.5 4.4 4.2 2.7 3.7 3.8 4.3 0.  3.9 2.8 3.  4.  3.1 5.  3.4
#  3.5 3.6 2.2 3.3 4.9 2.6 3.2 2.3 2.1 2.9 2.  1.  2.5 2.4 4.8 1.9 1.4 1.7
#  1.8]

# %%
df_full1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         505 non-null    object
#  1   Bus_type         489 non-null    object
#  2   Start_time       505 non-null    object
#  3   End_time         505 non-null    object
#  4   Total_duration   505 non-null    object
#  5   Price            1087 non-null   float64
#  6   Seats_Available  495 non-null    object
#  7   Ratings          1087 non-null   float64
#  8   Route_link       1087 non-null   object
#  9   Route_name       1087 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 85.1+ KB

# %%
df_full1.fillna(0,inplace=True)

# %%
df_full1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1087 non-null   object
#  1   Bus_type         1087 non-null   object
#  2   Start_time       1087 non-null   object
#  3   End_time         1087 non-null   object
#  4   Total_duration   1087 non-null   object
#  5   Price            1087 non-null   float64
#  6   Seats_Available  1087 non-null   object
#  7   Ratings          1087 non-null   float64
#  8   Route_link       1087 non-null   object
#  9   Route_name       1087 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 85.1+ KB

# %%
#change dataframe to csv
path=r"C:/Users/kumar/Desktop/scraped_data/complete_busdetails_cleaned.csv"
df_full1.to_csv(path,index=False)

# %% [markdown]
# CREATING A MYSQL DATABASE:

# %%
import mysql.connector
from mysql.connector import Error

def connect_to_local_mysql():
    try:
        connection = mysql.connector.connect(
            host="localhost",      
            user="deepu",  
            password="Ashokkumar1#", 
            database="redbus",  
            port=3306              
        )
        
        if connection.is_connected():
            print("Connected to MySQL database!")
            
            cursor = connection.cursor()
            cursor.execute("SELECT DATABASE();")
            database_name = cursor.fetchone()
            print(f"You're connected to database: {database_name[0]}")
            
            #cursor.close()
            #connection.close()
            #print("MySQL connection closed.")
    except Error as e:
        print(f"Error: {e}")
        
connect_to_local_mysql()
# Out:
# Connected to MySQL database!
# You're connected to database: redbus

# %%
import mysql.connector

connection = mysql.connector.connect(
  host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
  port = 4000,
  user = "3pfcj99ALRDvUDL.root",
  password = "baGcmviDrM0uEsYF",)
print(connection)
mycursor = connection.cursor(buffered=True)

# %%
#sql connection
conn=mysql.connector.connect(host="localhost", user="deepu", password="Ashokkumar1#",database="redbus")
my_cursor = conn.cursor()
my_cursor.execute("CREATE DATABASE IF NOT EXISTS redbus")

# %% [markdown]
# TABLE CREATION

# %%
my_cursor.execute("""CREATE TABLE IF NOT EXISTS bus_details(
                  ID INT AUTO_INCREMENT PRIMARY KEY,
                  Bus_name VARCHAR(255) NOT NULL,
                  Bus_type VARCHAR(255) NOT NULL,
                  Start_time VARCHAR(255) NOT NULL,
                  End_time VARCHAR(255) NOT NULL,
                  Total_duration VARCHAR(255) NOT NULL,
                  Price FLOAT default 0,
                  Seats_Available VARCHAR(255) NOT NULL,
                  Ratings FLOAT NULL,
                  routelink VARCHAR(255) NULL,
                  route VARCHAR(255) NULL
                  )""")
print("MySQL Table Created in redbus Database Successfully!")
# Out:
# MySQL Table Created in redbus Database Successfully!

# %%
import pandas as pd 
df_full1=pd.read_csv(r"C:\Users\kumar\Desktop\scraped_data\complete_busdetails_cleaned.csv")
df_full1
# Out:
#                                     Bus_name  \
# 0                                   FRESHBUS
# 1                                   FRESHBUS
# 2                                   FRESHBUS
# 3                           AdSai RK Travels
# 4     RAMK HOLIDAYS (GMRK TOURS AND TRAVELS)
# ...                                      ...
# 1082                          Laxmi holidays
# 1083                                       0
# 1084                                       0
# 1085                                       0
# 1086                                       0
#
#                                    Bus_type Start_time End_time  \
# 0                 Electric A/C Seater (2+2)      22:40    05:45
# 1                 Electric A/C Seater (2+2)      22:55    05:55
# 2                 Electric A/C Seater (2+2)      23:35    06:30
# 3            Non A/C Seater / Sleeper (2+1)      21:50    04:35
# 4              Volvo A/C Semi Sleeper (2+2)      22:30    05:25
# ...

# %%
truncate_query = "TRUNCATE TABLE bus_details;"
my_cursor.execute(truncate_query)  # Execute the TRUNCATE statement
conn.commit()  # Commit the transaction

# %%
insert_query = """
INSERT INTO bus_details (
    Bus_name,
    Bus_type,
    Start_time,
    End_time,
    Total_duration,
    Price,
    Seats_Available,
    Ratings,
    routelink,
    route
)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
ON DUPLICATE KEY UPDATE
    Bus_type = VALUES(Bus_type),
    End_time = VALUES(End_time),
    Total_duration = VALUES(Total_duration),
    Price = VALUES(Price),
    Seats_Available = VALUES(Seats_Available),
    Ratings = VALUES(Ratings),
    routelink = VALUES(routelink);
"""

data=df_full1.values.tolist()
my_cursor.executemany(insert_query,data)
conn.commit()

# %%
import mysql.connector
conn = mysql.connector.connect(
    host="localhost",
    user="deepu",
    password="Ashokkumar1#",
    database="redbus"
)
my_cursor = conn.cursor()
print("Connected to the 'redbus' database.")

my_cursor.execute("SELECT * FROM bus_details")  
rows = my_cursor.fetchall()
for row in rows:
    print(row)
# Out:
# Connected to the 'redbus' database.
# (1, 'FRESHBUS', 'Electric A/C Seater (2+2)', '22:40', '05:45', '07h 05m', 449.0, '12 Seats available', 4.7, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# (2, 'FRESHBUS', 'Electric A/C Seater (2+2)', '22:55', '05:55', '07h 00m', 449.0, '18 Seats available', 4.6, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# (3, 'FRESHBUS', 'Electric A/C Seater (2+2)', '23:35', '06:30', '06h 55m', 449.0, '11 Seats available', 4.6, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# (4, 'AdSai RK Travels', 'Non A/C Seater / Sleeper (2+1)', '21:50', '04:35', '06h 45m', 560.0, '12 Seats available', 4.1, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# ...

# %%
my_cursor.execute("SELECT  COUNT(DISTINCT route) AS RouteCount  FROM bus_details")
rows = my_cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (119,)

# %%
#mycursor.execute("DELETE FROM bus_details WHERE Bus_name IS NULL OR Bus_type IS NULL OR Price IS NULL")
my_cursor.execute("DELETE FROM bus_details WHERE Bus_name = '0' OR Bus_type = '0' OR Price = '0'")
conn.commit()  
print("Rows with NULL values in Bus_name, Bus_type, or Price have been deleted.")
# Out:
# Rows with NULL values in Bus_name, Bus_type, or Price have been deleted.

# %%
my_cursor.execute("SELECT * FROM bus_details")  
rows = my_cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'FRESHBUS', 'Electric A/C Seater (2+2)', '22:40', '05:45', '07h 05m', 449.0, '12 Seats available', 4.7, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# (2, 'FRESHBUS', 'Electric A/C Seater (2+2)', '22:55', '05:55', '07h 00m', 449.0, '18 Seats available', 4.6, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# (3, 'FRESHBUS', 'Electric A/C Seater (2+2)', '23:35', '06:30', '06h 55m', 449.0, '11 Seats available', 4.6, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# (4, 'AdSai RK Travels', 'Non A/C Seater / Sleeper (2+1)', '21:50', '04:35', '06h 45m', 560.0, '12 Seats available', 4.1, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# ...

# %%
my_cursor.execute("""
    DELETE FROM bus_details 
    WHERE Bus_name IS NULL 
    OR Bus_type IS NULL 
    OR Price IS NULL 
    OR Price = 0               
""")
conn.commit()
print("Rows with NULL values or NaN in Bus_name, Bus_type, or Price have been deleted.")
# Out:
# Rows with NULL values or NaN in Bus_name, Bus_type, or Price have been deleted.

# %%
my_cursor.execute("SELECT * FROM bus_details")  
rows = my_cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'FRESHBUS', 'Electric A/C Seater (2+2)', '22:40', '05:45', '07h 05m', 449.0, '12 Seats available', 4.7, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# (2, 'FRESHBUS', 'Electric A/C Seater (2+2)', '22:55', '05:55', '07h 00m', 449.0, '18 Seats available', 4.6, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# (3, 'FRESHBUS', 'Electric A/C Seater (2+2)', '23:35', '06:30', '06h 55m', 449.0, '11 Seats available', 4.6, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# (4, 'AdSai RK Travels', 'Non A/C Seater / Sleeper (2+1)', '21:50', '04:35', '06h 45m', 560.0, '12 Seats available', 4.1, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'Hyderabad to Vijayawada')
# ...
